# %% [markdown]
# ## Example: how to save plots in the figures/ folder

# %%
# 1. Gjør at notebooken finner mappen src/
import sys
sys.path.append("..")

# 2. Vanlige importer
import numpy as np
import matplotlib.pyplot as plt
from src.plotting import save_fig

# %% [markdown]
# Eneste endringen er egentlig at man må ha importe `sys` så notebooken finner `src`. I tillegg kan man legge til dette under for å laste inn kode fra src på nytt hver gang man kjører en celle. Da ser man endringer som gjøres i f.eks. models.py uten å måtte restarte kernel osv.

# %%
# 3. Valgfritt: last inn src/ på nytt når koden der endres
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Her er eksempel på plot som legger seg i figures/

# %%
x = np.linspace(-1, 1, 200)
y = 1 / (1 + 25 * x**2)   # Runge-funksjonen

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Runge function")
save_fig("notebook_test")   # lagrer figures/notebook_test.pdf
plt.show()
